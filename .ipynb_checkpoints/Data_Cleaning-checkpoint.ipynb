# %%
import pandas as pd
df = pd.read_csv("US_DS_jobs.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#    Unnamed: 0                Job Title               Salary Estimate  \
# 0           0       FCC Data Scientist   $73k-$121k (Glassdoor Est.)
# 1           1  Research Data Scientist   $72k-$120k (Glassdoor Est.)
# 2           2       Research Scientist                            -1
# 3           3   Staff Data Scientist I  $127k-$203k (Glassdoor Est.)
# 4           4  Analytics Data Engineer    $37k-$75k (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Summary: The FCC Analytics group is responsibl...     3.0
# 1  IAI is looking for a talented research scienti...     3.6
# 2  Making a Material Difference is at the core of...     3.6
# 3  Data Scientist – Machine Learning & Real-Time ...     3.4
# 4  Job Description:\n\nAs an Analytics Data Engin...     4.4
#
#                   Company Name         Location  Headquarters  \
# 0              BankUnited\n3.0  Miami Lakes, FL            -1
# 1  Intelligent Automation\n3.6    Rockville, MD            -1
# 2                   Veeco\n3.6    Plainview, NY            -1
# 3                Valassis\n3.4  Morrisville, NC            -1
# 4     Progressive Leasing\n4.4       Draper, UT            -1
#
#                      Size  Founded  Type of ownership  \
# 0  1001 to 5000 Employees     2009   Company - Public
# 1     51 to 200 Employees     1987  Company - Private
# 2  1001 to 5000 Employees     1945   Company - Public
# 3  1001 to 5000 Employees     1970  Company - Private
# 4  1001 to 5000 Employees     1999   Company - Public
#
#                            Industry             Sector  \
# 0             Banks & Credit Unions            Finance
# 1         Health, Beauty, & Fitness  Consumer Services
# 2          Industrial Manufacturing      Manufacturing
# 3           Advertising & Marketing  Business Services
# 4  Financial Transaction Processing            Finance
#
#                       Revenue  Competitors
# 0          $10+ billion (USD)           -1
# 1    $25 to $50 million (USD)           -1
# 2  $100 to $500 million (USD)           -1
# 3    Unknown / Non-Applicable           -1
# 4      $2 to $5 billion (USD)           -1

# %%
#Cleans the columns which are not needed
df.drop("Unnamed: 0", axis = 1, inplace=True)
df.drop("Headquarters", axis=1, inplace=True)
df.drop("Competitors", axis=1, inplace=True)

#Dropping all the duplicate records
df.drop_duplicates(inplace = True)

# %%
df.head()
# Out:
#                  Job Title               Salary Estimate  \
# 0       FCC Data Scientist   $73k-$121k (Glassdoor Est.)
# 1  Research Data Scientist   $72k-$120k (Glassdoor Est.)
# 2       Research Scientist                            -1
# 3   Staff Data Scientist I  $127k-$203k (Glassdoor Est.)
# 4  Analytics Data Engineer    $37k-$75k (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Summary: The FCC Analytics group is responsibl...     3.0
# 1  IAI is looking for a talented research scienti...     3.6
# 2  Making a Material Difference is at the core of...     3.6
# 3  Data Scientist – Machine Learning & Real-Time ...     3.4
# 4  Job Description:\n\nAs an Analytics Data Engin...     4.4
#
#                   Company Name         Location                    Size  \
# 0              BankUnited\n3.0  Miami Lakes, FL  1001 to 5000 Employees
# 1  Intelligent Automation\n3.6    Rockville, MD     51 to 200 Employees
# 2                   Veeco\n3.6    Plainview, NY  1001 to 5000 Employees
# 3                Valassis\n3.4  Morrisville, NC  1001 to 5000 Employees
# 4     Progressive Leasing\n4.4       Draper, UT  1001 to 5000 Employees
#
#    Founded  Type of ownership                          Industry  \
# 0     2009   Company - Public             Banks & Credit Unions
# 1     1987  Company - Private         Health, Beauty, & Fitness
# 2     1945   Company - Public          Industrial Manufacturing
# 3     1970  Company - Private           Advertising & Marketing
# 4     1999   Company - Public  Financial Transaction Processing
#
#               Sector                     Revenue
# 0            Finance          $10+ billion (USD)
# 1  Consumer Services    $25 to $50 million (USD)
# 2      Manufacturing  $100 to $500 million (USD)
# 3  Business Services    Unknown / Non-Applicable
# 4            Finance      $2 to $5 billion (USD)

# %%
#Cleaning Salary Estimate column
df = df[df['Salary Estimate'] != '-1']
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])
minus_kd = salary.apply(lambda x: x.replace('k', "").replace('$',"").replace('-'," "))
minus_perhr = minus_kd.apply(lambda x: x.lower().replace('per hour', ""))

# %%
#Adding new features for the Salary Estimate column
df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['min_salary'] = minus_perhr.apply(lambda x: int(x.split()[0]))
df['max_salary'] = minus_perhr.apply(lambda x: int(x.split()[1]))
df['avg_salary'] = df['min_salary'] + df['max_salary'] / 2

# %%
#Cleaning Company name column
df['Cleaned_company_name'] = df.apply(lambda x: x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-4], axis=1)

# %%
#Creating and Cleaning the State Column from Location
df['State'] = df['Location'].apply(lambda x: x.split(',')[-1])
df['State'] = df['State'].apply(lambda x: x.replace('Maryland','MD'))
df['State'] = df['State'].apply(lambda x: x.replace('United States','USA'))
df['State'] = df['State'].apply(lambda x: x.replace('Virginia','VA'))
df['State'] = df['State'].apply(lambda x: x.replace('North Carolina','NC'))
df['State'] = df['State'].apply(lambda x: x.replace('Bristol','TN'))
df['State'] = df['State'].apply(lambda x: x.replace('California','CA'))
df['State'] = df['State'].apply(lambda x: x.replace('Utah','UT'))
df['State'] = df['State'].apply(lambda x: x.strip())

#Creating the city column from the location column 
df['City'] = df['Location'].apply(lambda x: x.split(',')[0])

# %%
#Creating the Age of the company column
df['Age'] = df['Founded'].apply(lambda x: x if x<1 else 2020 - x)

# %%
#language features
#Python
df['Python'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
#Java
df['Java'] = df['Job Description'].apply(lambda x: 1 if 'java' in x.lower() else 0)
#SQL
df['SQL'] = df['Job Description'].apply(lambda x: 1 if 'sql' in x.lower() else 0)
#Scala
df['Scala'] = df['Job Description'].apply(lambda x: 1 if 'scala' in x.lower() else 0)
#Spark
df['Spark'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
#Hadoop
df['Hadoop'] = df['Job Description'].apply(lambda x: 1 if 'hadoop' in x.lower() else 0)
#Yarn
df['Yarn'] = df['Job Description'].apply(lambda x: 1 if 'yarn' in x.lower() else 0)
#AWS
df['AWS'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
#Tableau
df['Tableau'] = df['Job Description'].apply(lambda x: 1 if 'tableau' in x.lower() else 0)
#Matplolib
df['Matplotlib'] = df['Job Description'].apply(lambda x: 1 if 'matplotlib' in x.lower() else 0)
#Pandas
df['Pandas'] = df['Job Description'].apply(lambda x: 1 if 'pandas' in x.lower() else 0)
#Seaborne
df['Seaborn'] = df['Job Description'].apply(lambda x: 1 if 'seaborn' in x.lower() else 0)
#Docker 
df['Docker'] = df['Job Description'].apply(lambda x: 1 if 'docker' in x.lower() else 0)
#Kubernetes 
df['Kubernetes'] = df['Job Description'].apply(lambda x: 1 if 'kubernetes' in x.lower() else 0)
#Neural Networks 
df['Neural Networks'] = df['Job Description'].apply(lambda x: 1 if 'neural networks' in x.lower()
                                                                or 'deep learning' in x.lower() else 0)
#R-Studio
df['R'] = df['Job Description'].apply(lambda x: 1 if 'r-studio' in x.lower()
                                                    or 'r studio' in x.lower() 
                                                     or ' r ' in x.lower() else 0)
#Nosql
df['Nosql'] = df['Job Description'].apply(lambda x: 1 if 'nosql' in x.lower() or
                                                        'cassandra' in x.lower() or
                                                         'mongodb' in x.lower() or
                                                         'dynamodb' in x.lower() else 0)

# %%
columns = df.columns
for language in list(columns[20:]):
    print(language)
    print(df[language].value_counts())
    print('\n')
# Out:
# Python
# 1    550
# 0    352
# Name: Python, dtype: int64
#
#
# Java
# 0    729
# 1    173
# Name: Java, dtype: int64
#
#
# SQL
# 1    494
# 0    408
# Name: SQL, dtype: int64
#
#
# Scala
# 0    697
# 1    205
# Name: Scala, dtype: int64
#
#
# Spark
# 0    713
# 1    189
# Name: Spark, dtype: int64
#
#
# Hadoop
# 0    759
# 1    143
# Name: Hadoop, dtype: int64
#
#
# Yarn
# 0    900
# 1      2
# Name: Yarn, dtype: int64
#
#
# AWS
# 0    671
# 1    231
# Name: AWS, dtype: int64
#
#
# Tableau
# 0    733
# 1    169
# Name: Tableau, dtype: int64
#
#
# Matplotlib
# 0    881
# 1     21
# Name: Matplotlib, dtype: int64
#
#
# Pandas
# 0    836
# 1     66
# Name: Pandas, dtype: int64
#
#
# Seaborn
# 0    897
# 1      5
# Name: Seaborn, dtype: int64
#
#
# Docker
# 0    872
# 1     30
# Name: Docker, dtype: int64
#
#
# Kubernetes
# 0    884
# 1     18
# Name: Kubernetes, dtype: int64
#
#
# Neural Networks
# 0    766
# 1    136
# Name: Neural Networks, dtype: int64
#
#
# R
# 0    813
# 1     89
# Name: R, dtype: int64
#
#
# Nosql
# 0    790
# 1    112
# Name: Nosql, dtype: int64

# %%
df.to_csv('US_DS_jobs_(Cleaned).csv', index = False)
